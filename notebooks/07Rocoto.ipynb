# %% [markdown]
# # Configuring Rocoto workflows
#
# The `uw rocoto` tool has three modes:
#
# * `realize` -- creates a Rocoto XML from a UW YAML
# * `validate` -- uses the UW framework to validate a Rocoto XML without needing to have a Rocoto installation
# * `iterate` -- runs a Rocoto XML to completion through a specified task
#
# For examples of how to use these CLI tools, go to the __[Rocoto UW docs](https://uwtools.readthedocs.io/en/main/sections/user_guide/cli/tools/rocoto.html)__.
#
# # Building a UW YAML for Rocoto
#
# We'll start by building a UW YAML config describing the Rocoto workflow that will run the cycling experiment's tasks. Use the __[UW YAML Rocoto Workflows](https://uwtools.readthedocs.io/en/main/sections/user_guide/yaml/rocoto.html)__ docs to get going.

# %%
import os
from pathlib import Path

# IN BASH: export configs=/path/to/uwtools_training/configs
os.environ["configs"] = str(Path(".").resolve().parent / "configs")

# %% [markdown]
# ## The workflow section

# %%
# !head -n 20 $configs/rocoto_workflow.yaml
# Out:
# user:
#   account: zrtrr
# workflow:
#   attrs:
#     realtime: false
#     scheduler: slurm
#   cycledef:
#     - attrs:
#         group: cold_start_cycle
#       spec: 202508271200 202508271200 01:00:00
#     - attrs:
#         group: prod
#       spec: 202508271300 202508271300 01:00:00
#   entities:
#     ACCOUNT: "{{ user.account }}"
#     LOGDIR: "{{ user.expt_dir}}/log"
#   log:
#     value: "{{ user.expt_dir }}/workflow.log"
#   tasks:
#     task_prepare_ics:

# %% [markdown]
# ## Adding a task
#
# Docs: __[Defining Tasks](https://uwtools.readthedocs.io/en/main/sections/user_guide/yaml/rocoto.html#defining-tasks)__
#
# * The UW YAML key should be `task_` followed by an arbitrary name. This name will be shown in `rocotostat` output.
# * Values can be string references to XML entities, Jinja2 expressions, hard-coded values.
# * Don't use the `--batch` flag when running UW drivers: Rocoto handles submitting jobs to the batch system.
# * Use Rocoto-supplied information for date-time flexibility.
# * A `jobname` variable, reflecting the arbitrary name following `task_`, will be supplied by `uwtools` for use in Jinja2 expressions.

# %% [markdown]
# # Check the progress
#
# Run the `uw rocoto realize` tool to validate the YAML and attempt to create an XML.

# %%
# !uw rocoto realize -c $configs/rocoto_workflow.yaml -o workflow.xml
# Out:
# Traceback (most recent call last):
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/bin/uw", line 9, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/cli.py", line 100, in main
#     sys.exit(0 if modes[args[STR.mode]](args) else 1)
#                   ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/cli.py", line 596, in _dispatch_rocoto
#     return actions[args[STR.action]](args)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/cli.py", line 620, in _dispatch_rocoto_realize
#     return uwtools.api.rocoto.realize(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         config=args[STR.cfgfile],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         output_file=args[STR.outfile],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         stdin_ok=True,
#         ^^^^^^^^^^^^^^
#     )
#     ^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/api/rocoto.py", line 40, in realize
#     _realize(
#     ~~~~~~~~^
#         config=_ensure_data_source(_str2path(config), stdin_ok), output_file=_str2path(output_file)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/rocoto.py", line 61, in realize
#     rxml = _RocotoXML(config)
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/rocoto.py", line 203, in __init__
#     self._config_validate(config)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/rocoto.py", line 497, in _config_validate
#     validate_yaml(
#     ~~~~~~~~~~~~~^
#         schema_file=resource_path("jsonschema/rocoto.jsonschema"),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         config_path=config_path,
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/config/validator.py", line 171, in validate_external
#     if not validate(schema=schema, desc=desc, config=config):
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/config/validator.py", line 79, in validate
#     errors = _validation_errors(config, schema)
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/config/validator.py", line 215, in _validation_errors
#     return list(validator.iter_errors(config))
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 384, in iter_errors
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 296, in properties
#     yield from validator.descend(
#     ...<4 lines>...
#     )
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 432, in descend
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 296, in properties
#     yield from validator.descend(
#     ...<4 lines>...
#     )
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 432, in descend
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 23, in patternProperties
#     yield from validator.descend(
#         v, subschema, path=k, schema_path=pattern,
#     )
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 432, in descend
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 275, in ref
#     yield from validator._validate_reference(ref=ref, instance=instance)
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 432, in descend
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 296, in properties
#     yield from validator.descend(
#     ...<4 lines>...
#     )
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/validators.py", line 432, in descend
#     for error in errors:
#                  ^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/jsonschema/_keywords.py", line 287, in type
#     yield ValidationError(f"{instance!r} is not of type {reprs}")
#                             ^^^^^^^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/config/support.py", line 201, in __repr__
#     return "%s %s" % (self.tag, self.converted)
#                                 ^^^^^^^^^^^^^^
#   File "/scratch3/BMC/wrfruc/cholt/conda/envs/uwtools-training/lib/python3.13/site-packages/uwtools/config/support.py", line 223, in converted
#     return dict(zip(UWYAMLConvert.TAGS, converters))[self.tag](self.value)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: '{{ analysis.gsi.execution.batchargs.cores }}'

# %% [markdown]
# ## OOPS!
# The `rocoto_workflow.yaml` doesn't have all the values it needs. Let's compose a more complete YAML on the fly.

# %%
# %%bash
# realize_args=(
#     -i $configs/prepare_bcs.yaml
#     -u $configs/rocoto_one_task.yaml
# )
#
# uw config realize ${realize_args[*]} | uw rocoto realize -o workflow.xml
# cat workflow.xml
# Out:
# [2025-09-23T15:39:52]     INFO Schema validation succeeded for Rocoto config
# [2025-09-23T15:39:52]     INFO Schema validation succeeded for Rocoto XML
# <?xml version='1.0' encoding='utf-8'?>
# <!DOCTYPE workflow [
#   <!ENTITY ACCOUNT "zrtrr">
#   <!ENTITY LOGDIR "/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/log">
# ]>
# <workflow realtime="False" scheduler="slurm">
#   <cycledef group="cold_start_cycle">202508271200 202508271200 01:00:00</cycledef>
#   <cycledef group="prod">202508271300 202508271300 01:00:00</cycledef>
#   <log>/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/workflow.log</log>
#   <task name="prepare_ics" cycledefs="cold_start_cycle">
#     <account>&ACCOUNT;</account>
#     <nodes>1:ppn=20</nodes>
#     <walltime>00:30:00</walltime>
#     <command>
#       <cyclestr>uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime 0 -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_ics</cyclestr>
#     </command>
#     <jobname>prepare_ics</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/prepare_ics_@Y@m@d@H.log</cyclestr>
#     </join>
#   </task>
# </workflow>

# %% [markdown]
# ## Adding a metatask
#
# Docs: __[Defining Metatasks](https://uwtools.readthedocs.io/en/main/sections/user_guide/yaml/rocoto.html#defining-metatasks)__
#
# * Metatask blocks require a `var:` block and one more `task_` or `metatask_` blocks.
# * The `var:` block has at least one key/value pair to define the iteration loop.

# %%
# %%bash
# realize_args=(
#     -i $configs/prepare_bcs.yaml
#     -u $configs/rocoto_with_metatask.yaml
# )
#
# uw config realize ${realize_args[*]} | uw rocoto realize -o workflow.xml
# Out:
# [2025-09-23T15:39:56]     INFO Schema validation succeeded for Rocoto config
# [2025-09-23T15:39:56]     INFO Schema validation succeeded for Rocoto XML

# %%
# !cat workflow.xml
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <!DOCTYPE workflow [
#   <!ENTITY ACCOUNT "zrtrr">
#   <!ENTITY LOGDIR "/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/log">
# ]>
# <workflow realtime="False" scheduler="slurm">
#   <cycledef group="cold_start_cycle">202508271200 202508271200 01:00:00</cycledef>
#   <cycledef group="prod">202508271300 202508271300 01:00:00</cycledef>
#   <log>/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/workflow.log</log>
#   <task name="prepare_ics" cycledefs="cold_start_cycle">
#     <account>&ACCOUNT;</account>
#     <nodes>1:ppn=20</nodes>
#     <walltime>00:30:00</walltime>
#     <command>
#       <cyclestr>uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime 0 -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_ics</cyclestr>
#     </command>
#     <jobname>prepare_ics</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/prepare_ics_@Y@m@d@H.log</cyclestr>
#     </join>
#   </task>
#   <metatask name="prepare_lbcs">
#     <var name="LEADTIME">0 1 2 3 4 5 </var>
#     <task name="prepare_ics_#LEADTIME#" cycledefs="cold_start_cycle">
#       <account>&ACCOUNT;</account>
#       <nodes>1:ppn=20</nodes>
#       <walltime>00:30:00</walltime>
#       <command>
#         <cyclestr>uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime #LEADTIME# -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_lbcs</cyclestr>
#       </command>
#       <jobname>prepare_ics_#LEADTIME#</jobname>
#       <join>
#         <cyclestr>&LOGDIR;/prepare_ics_#LEADTIME#_@Y@m@d@H.log</cyclestr>
#       </join>
#     </task>
#   </metatask>
# </workflow>

# %% [markdown]
# ## Adding dependencies to a task
#
# Docs: __[The dependency: key](https://uwtools.readthedocs.io/en/main/sections/user_guide/yaml/rocoto.html#the-dependency-key)__
#
# * UW Rocoto YAML follows the same structure as Rocoto XML
# * YAML keys must be unique at the same level, so all *dependencies* take an optional suffix after an underscore, e.g., `_arbitrary`, where `arbitrary` can be any unique string identifier. This identifier is not used by Rocoto, but is used when referenced by Jinja2 expressions. While they are not required, they can also be useful to make some dependencies clearer and more human-readable.

# %%
# %%bash
# uw config realize -i $configs/fv3_config.yaml -u $configs/gsi_config.yaml | \
#     uw config realize -u $configs/prepare_bcs.yaml | \
#     uw config realize -u $configs/rocoto_workflow.yaml | \
#     uw rocoto realize -o workflow.xml
# Out:
# [2025-09-23T15:40:07]     INFO Schema validation succeeded for Rocoto config
# [2025-09-23T15:40:08]     INFO Schema validation succeeded for Rocoto XML

# %%
# !cat workflow.xml
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <!DOCTYPE workflow [
#   <!ENTITY ACCOUNT "zrtrr">
#   <!ENTITY LOGDIR "/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/log">
# ]>
# <workflow realtime="False" scheduler="slurm">
#   <cycledef group="cold_start_cycle">202508271200 202508271200 01:00:00</cycledef>
#   <cycledef group="prod">202508271300 202508271300 01:00:00</cycledef>
#   <log>/scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/workflow.log</log>
#   <task name="prepare_ics" cycledefs="cold_start_cycle">
#     <account>&ACCOUNT;</account>
#     <nodes>1:ppn=20</nodes>
#     <walltime>00:30:00</walltime>
#     <command>
#       <cyclestr>uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime 0 -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_ics</cyclestr>
#     </command>
#     <jobname>prepare_ics</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/prepare_ics_@Y@m@d@H.log</cyclestr>
#     </join>
#   </task>
#   <metatask name="prepare_lbcs">
#     <var name="LEADTIME">0 1 2 3 4 5 </var>
#     <task name="prepare_ics_#LEADTIME#" cycledefs="cold_start_cycle">
#       <account>&ACCOUNT;</account>
#       <nodes>1:ppn=20</nodes>
#       <walltime>00:30:00</walltime>
#       <command>
#         <cyclestr>uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime #LEADTIME# -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_lbcs</cyclestr>
#       </command>
#       <jobname>prepare_ics_#LEADTIME#</jobname>
#       <join>
#         <cyclestr>&LOGDIR;/prepare_ics_#LEADTIME#_@Y@m@d@H.log</cyclestr>
#       </join>
#     </task>
#   </metatask>
#   <task name="forecast_coldstart" cycledefs="cold_start_cycle">
#     <account>&ACCOUNT;</account>
#     <nodes>4:ppn=21</nodes>
#     <walltime>00:45:00</walltime>
#     <command>
#       <cyclestr>uw fv3 run --cycle @Y-@m-@dT@H -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/fv3_config.yaml --key-path forecast_prod</cyclestr>
#     </command>
#     <jobname>forecast_coldstart</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/forecast_coldstart_@Y@m@d@H.log</cyclestr>
#     </join>
#     <dependency>
#       <and>
#         <taskdep task="prepare_ics"/>
#         <metataskdep metatask="prepare_lbcs"/>
#       </and>
#     </dependency>
#   </task>
#   <task name="analysis" cycledefs="prod">
#     <account>&ACCOUNT;</account>
#     <cores>120</cores>
#     <walltime>00:50:00</walltime>
#     <command>
#       <cyclestr>uw gsi run --cycle @Y-@m-@dT@H -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/gsi_uw_config.yaml --key-path analysis</cyclestr>
#     </command>
#     <jobname>analysis</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/analysis_@Y@m@d@H.log</cyclestr>
#     </join>
#     <dependency>
#       <or>
#         <taskdep cycle_offset="-01:00:00" task="forecast_coldstart"/>
#         <taskdep cycle_offset="-01:00:00" task="forecast_cycled"/>
#       </or>
#     </dependency>
#   </task>
#   <task name="forecast_cycled" cycledefs="prod">
#     <account>&ACCOUNT;</account>
#     <nodes>4:ppn=21</nodes>
#     <walltime>00:45:00</walltime>
#     <command>
#       <cyclestr>/scratch3/BMC/wrfruc/uw_training/uwtools_training/scripts/run_forecast.sh /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/fv3_config.yaml @Y-@m-@dT@H</cyclestr>
#     </command>
#     <jobname>forecast_cycled</jobname>
#     <join>
#       <cyclestr>&LOGDIR;/forecast_cycled_@Y@m@d@H.log</cyclestr>
#     </join>
#     <dependency>
#       <taskdep task="analysis"/>
#     </dependency>
#   </task>
# </workflow>

# %% [markdown]
# ## Use `compose` tool
#
# * A helper tool that reduces the need for repeated piping.
# * Configs increase in priority from left to right. Last one takes most precedence.

# %%
# %%bash
# file_list=(
#     $configs/fv3_config.yaml
#     $configs/gsi_config.yaml
#     $configs/prepare_bcs.yaml
#     $configs/rocoto_workflow.yaml
# )
# uw config compose ${file_list[*]} -o experiment.yaml

# %%
# !cat experiment.yaml
# Out:
# timevars:
#   pyyyymmddhh: '{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}'
#   pyyyymmdd: '{{ (cycle - user.cycle_int).strftime("%Y%m%d") }}'
#   yyyymmddhh: '{{ cycle.strftime("%Y%m%d%H") }}'
#   yyyymmdd: '{{ cycle.strftime("%Y%m%d") }}'
#   hh: '{{ cycle.strftime("%H") }}'
#   yyyy: '{{ cycle.strftime("%Y") }}'
#   mm: '{{ cycle.strftime("%m") }}'
#   dd: '{{ cycle.strftime("%d") }}'
#   fff: '{{ "%03d" % (leadtime.total_seconds() / 3600) }}'
# user:
#   uw_training: /scratch3/BMC/wrfruc/uw_training/uwtools_training
#   expt_dir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7
#   rrfs_workflow: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow
#   physics_suite: FV3_HRRR_gf
#   cycle_int: !timedelta '1'
#   account: zrtrr
#   cycle_freq: !timedelta '1'
# platform:
#   scheduler: slurm
#   fix: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS
#   fix_am: '{{ platform.fix }}/am'
#   fix_lam: '{{ platform.fix }}/lam/RRFS_CONUS_13km_Lake_fracSV'
#   input_data: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data
#   gsi_fixdir: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi
#   crtm_fixdir: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix
#   obspath: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs
# forecast_prod:
#   fv3:
#     diag_table: &id001
#       template_file: '{{ user.uw_training }}/parm/diag_table.{{ user.physics_suite }}'
#       template_values:
#         cres: C775
#         starttime: !datetime "{{ cycle }}"
#     domain: regional
#     execution: &id002
#       batchargs:
#         nodes: 4
#         tasks_per_node: 21
#         walltime: 00:45:00
#       envcmds:
#       - ulimit -s unlimited
#       - module use {{ user.rrfs_workflow }}/modulefiles
#       - module load build_hera_intel
#       executable: '{{ user.rrfs_workflow }}/exec/ufs_model'
#       mpiargs:
#       - --export=ALL
#       - --mem=0
#       mpicmd: srun
#       threads: 1
#     field_table: &id003
#       base_file: '{{ user.rrfs_workflow }}/parm/field_table.{{ user.physics_suite }}'
#     files_to_copy:
#       INPUT/gfs_ctrl.nc: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/ics/gfs_ctrl.nc'
#       INPUT/gfs_data.nc: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/ics/out.atm.tile7.nc'
#       INPUT/sfc_data.nc: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/ics/out.sfc.tile7.nc'
#       ufs.configure: '{{ user.uw_training }}/parm/ufs.configure'
#       fd_ufs.yaml: '{{ user.uw_training }}/parm/fd_ufs.yaml'
#     files_to_link: &id004
#       INPUT/grid_spec.nc: '{{ platform.fix_lam }}/C775_mosaic.halo3.nc'
#       INPUT/grid.tile7.halo4.nc: '{{ platform.fix_lam }}/C775_grid.tile7.halo4.nc'
#       INPUT/C775_grid.tile7.halo3.nc: '{{ platform.fix_lam }}/C775_grid.tile7.halo3.nc'
#       INPUT/oro_data.nc: '{{ platform.fix_lam }}/C775_oro_data.tile7.halo0.nc'
#       INPUT/oro_data.tile7.halo4.nc: '{{ platform.fix_lam }}/C775_oro_data.tile7.halo4.nc'
#       INPUT/oro_data_ls.nc: '{{ platform.fix_lam }}/C775_oro_data_ls.tile7.halo0.nc'
#       INPUT/oro_data_ss.nc: '{{ platform.fix_lam }}/C775_oro_data_ss.tile7.halo0.nc'
#       aerosol.dat: '{{ platform.fix_am }}/global_climaeropac_global.txt'
#       co2historicaldata_2010.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2010.txt'
#       co2historicaldata_2011.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2011.txt'
#       co2historicaldata_2012.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2012.txt'
#       co2historicaldata_2013.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2013.txt'
#       co2historicaldata_2014.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2014.txt'
#       co2historicaldata_2015.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2015.txt'
#       co2historicaldata_2016.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2016.txt'
#       co2historicaldata_2017.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2017.txt'
#       co2historicaldata_2018.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2018.txt'
#       co2historicaldata_2019.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2019.txt'
#       co2historicaldata_2020.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2020.txt'
#       co2historicaldata_2021.txt: '{{ platform.fix_am }}/fix_co2_proj/global_co2historicaldata_2021.txt'
#       co2historicaldata_glob.txt: '{{ platform.fix_am }}/global_co2historicaldata_glob.txt'
#       co2monthlycyc.txt: '{{ platform.fix_am }}/co2monthlycyc.txt'
#       global_h2oprdlos.f77: '{{ platform.fix_am }}/global_h2o_pltc.f77'
#       global_albedo4.1x1.grb: '{{ platform.fix_am }}/global_albedo4.1x1.grb'
#       global_zorclim.1x1.grb: '{{ platform.fix_am }}/global_zorclim.1x1.grb'
#       global_tg3clim.2.6x1.5.grb: '{{ platform.fix_am }}/global_tg3clim.2.6x1.5.grb'
#       sfc_emissivity_idx.txt: '{{ platform.fix_am }}/global_sfc_emissivity_idx.txt'
#       solarconstant_noaa_an.txt: '{{ platform.fix_am }}/global_solarconstant_noaa_an.txt'
#       global_o3prdlos.f77: '{{ platform.fix_am }}/ozprdlos_2015_new_sbuvO3_tclm15_nuchem.f77'
#       CCN_ACTIVATE.BIN: '{{ platform.fix_am }}/CCN_ACTIVATE.BIN'
#       freezeH2O.dat: '{{ platform.fix_am }}/freezeH2O.dat'
#       qr_acr_qg.dat: '{{ platform.fix_am }}/qr_acr_qg.dat'
#       qr_acr_qgV2.dat: '{{ platform.fix_am }}/qr_acr_qgV2.dat'
#       qr_acr_qs.dat: '{{ platform.fix_am }}/qr_acr_qs.dat'
#       qr_acr_qsV2.dat: '{{ platform.fix_am }}/qr_acr_qsV2.dat'
#       Thompson_MP_MONTHLY_CLIMO.nc: '{{ platform.fix_am }}/Thompson_MP_MONTHLY_CLIMO.nc'
#       <optics_file>: !glob '{{ platform.fix_am }}/optics_*.dat'
#       <aeroclim_file>: !glob '{{ platform.fix_am }}/aeroclim.m*.nc'
#     lateral_boundary_conditions:
#       interval_hours: 1
#       offset: 0
#       path: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/lbcs/{{ timevars.yyyymmddhh }}_{forecast_hour:03d}/gfs.bndy.nc'
#     length: 3
#     model_configure:
#       update_values:
#         start_year: &id005 !int '{{ cycle.year }}'
#         start_month: &id006 !int '{{ cycle.month }}'
#         start_day: &id007 !int '{{ cycle.day }}'
#         start_hour: &id008 !int '{{ cycle.hour }}'
#         start_minute: &id009 !int '{{ cycle.minute }}'
#         start_second: &id010 !int '{{ cycle.second }}'
#         nhours_fcst: &id011 !int '{{ forecast_prod.fv3.length }}'
#         fhrot: 0
#         run_continue: false
#         ens_sps: false
#         dt_atmos: 120
#         calendar: julian
#         memuse_verbose: false
#         restart_interval: 1
#         output_1st_tstep_rst: false
#         write_dopost: false
#         ideflate: 0
#         nbits: 0
#         ichunk2d: -1
#         jchunk2d: -1
#         ichunk3d: -1
#         jchunk3d: -1
#         kchunk3d: -1
#         itasks: 1
#         quilting: true
#         write_groups: 1
#         write_tasks_per_group: 4
#         num_files: 2
#         filename_base: dyn phy
#         output_file: netcdf netcdf
#         output_fh: 1  -1
#         nsout: -1
#         output_grid: lambert_conformal
#         cen_lon: -97.5
#         cen_lat: 38.5
#         stdlat1: 38.5
#         stdlat2: 38.5
#         nx: 420
#         ny: 252
#         dx: 13000.0
#         dy: 13000.0
#     namelist:
#       base_file: '{{ user.uw_training }}/parm/input.nml'
#     rundir: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/fcst'
#   platform:
#     scheduler: '{{ platform.scheduler }}'
#     account: '{{ user.account }}'
# cycled_forecast:
#   fv3:
#     diag_table: *id001
#     domain: regional
#     execution: *id002
#     field_table: *id003
#     files_to_copy:
#       INPUT/fv_core.res.tile1.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_core.res.tile1.nc'
#       INPUT/fv_srf_wnd.res.tile1.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_srf_wnd.res.tile1.nc'
#       INPUT/fv_tracer.res.tile1.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_tracer.res.tile1.nc'
#       INPUT/phy_data.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.phy_data.nc'
#       INPUT/sfc_data.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.sfc_data.nc'
#       INPUT/bk_coupler.res: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.coupler.res'
#       INPUT/fv_core.res.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_core.res.nc'
#       INPUT/gfs_ctrl.nc: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/INPUT/gfs_ctrl.nc'
#       ufs.configure: '{{ user.uw_training }}/parm/ufs.configure'
#       fd_ufs.yaml: '{{ user.uw_training }}/parm//fd_ufs.yaml'
#     files_to_link: *id004
#     lateral_boundary_conditions:
#       interval_hours: 1
#       offset: 1
#       path: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/lbcs/{{ timevars.pyyyymmddhh }}_{forecast_hour:03d}/gfs.bndy.nc'
#     length: 3
#     model_configure:
#       update_values:
#         start_year: *id005
#         start_month: *id006
#         start_day: *id007
#         start_hour: *id008
#         start_minute: *id009
#         start_second: *id010
#         nhours_fcst: *id011
#         fhrot: 0
#         run_continue: true
#         ens_sps: false
#         dt_atmos: 120
#         calendar: julian
#         memuse_verbose: false
#         restart_interval: 1
#         output_1st_tstep_rst: false
#         write_dopost: false
#         ideflate: 0
#         nbits: 0
#         ichunk2d: -1
#         jchunk2d: -1
#         ichunk3d: -1
#         jchunk3d: -1
#         kchunk3d: -1
#         itasks: 1
#         quilting: true
#         write_groups: 1
#         write_tasks_per_group: 4
#         num_files: 2
#         filename_base: dyn phy
#         output_file: netcdf netcdf
#         output_fh: 1  -1
#         nsout: -1
#         output_grid: lambert_conformal
#         cen_lon: -97.5
#         cen_lat: 38.5
#         stdlat1: 38.5
#         stdlat2: 38.5
#         nx: 420
#         ny: 252
#         dx: 13000.0
#         dy: 13000.0
#     namelist:
#       base_file: '{{ user.uw_training }}/parm/input.nml'
#       update_values:
#         fv_core_nml:
#           external_ic: false
#           make_nh: false
#           mountain: true
#           na_init: 0
#           nggps_ic: false
#           warm_start: true
#         gfs_physics_nml:
#           lsoil: 9
#     rundir: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/fcst'
#   platform:
#     scheduler: '{{ platform.scheduler }}'
#     account: '{{ user.account }}'
# forecast:
#   fv3:
#     rundir: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst'
# gsi:
#   foo: bar
# analysis:
#   gsi:
#     execution:
#       batchargs:
#         walltime: 00:50:00
#         cores: 120
#         exclusive: true
#       executable: '{{ user.rrfs_workflow }}/exec/gsi.x'
#       envcmds:
#       - module use {{ user.rrfs_workflow }}/modulefiles
#       - module load build_hera_intel
#       - ulimit -s unlimited
#       mpicmd: srun
#       stacksize: 300M
#       threads: 1
#     coupler.res:
#       template_file: '{{ platform.gsi_fixdir }}/RRFS_CONUS_13km/fv3_coupler.res'
#       template_values:
#         yyyy: '{{ timevars.yyyy }}'
#         mm: '{{ timevars.mm }}'
#         dd: '{{ timevars.dd }}'
#         hh: '{{ timevars.hh }}'
#         crh: '{{ gsi.foo }}'
#     files_to_copy:
#       anavinfo: '{{ platform.gsi_fixdir }}/anavinfo.rrfs_conv_dbz'
#       berror_stats: '{{ platform.gsi_fixdir }}/rrfs_glb_berror.l127y770.f77'
#       satinfo: '{{ platform.gsi_fixdir }}/global_satinfo.txt'
#       convinfo: '{{ platform.gsi_fixdir }}/convinfo.rrfs'
#       ozinfo: '{{ platform.gsi_fixdir }}/global_ozinfo.txt'
#       pcpinfo: '{{ platform.gsi_fixdir }}/global_pcpinfo.txt'
#       errtable: '{{ platform.gsi_fixdir }}/errtable.rrfs'
#       atms_beamwidth.txt: '{{ platform.gsi_fixdir }}/atms_beamwidth.txt'
#     files_to_link:
#       fv3_akbk: '{{ platform.gsi_fixdir }}/RRFS_CONUS_13km/fv3_akbk'
#       fv3_grid_spec: '{{ platform.gsi_fixdir }}/RRFS_CONUS_13km/fv3_grid_spec'
#       fv3_dynvars: '{{ forecast.fv3.rundir }}/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_core.res.tile1.nc'
#       fv3_tracer: '{{ forecast.fv3.rundir }}/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.fv_tracer.res.tile1.nc'
#       fv3_sfcdata: '{{ forecast.fv3.rundir }}/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.sfc_data.nc'
#       fv3_phyvars: '{{ forecast.fv3.rundir }}/RESTART/{{ timevars.yyyymmdd }}.{{ timevars.hh }}0000.phy_data.nc'
#       crtm_coeffs/Nalli.IRwater.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/Nalli.IRwater.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.IRice.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.IRice.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.IRsnow.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.IRsnow.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.IRland.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.IRland.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.VISice.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.VISice.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.VISland.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.VISland.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.VISsnow.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.VISsnow.EmisCoeff.bin'
#       crtm_coeffs/NPOESS.VISwater.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/NPOESS.VISwater.EmisCoeff.bin'
#       crtm_coeffs/FASTEM6.MWwater.EmisCoeff.bin: '{{ platform.crtm_fixdir }}/FASTEM6.MWwater.EmisCoeff.bin'
#       crtm_coeffs/AerosolCoeff.bin: '{{ platform.crtm_fixdir }}/AerosolCoeff.bin'
#       crtm_coeffs/CloudCoeff.bin: '{{ platform.crtm_fixdir }}/CloudCoeff.bin'
#       crtm_coeffs/<tau>: !glob "{{ platform.crtm_fixdir }}/*TauCoeff.bin"
#       crtm_coeffs/<spc>: !glob "{{ platform.crtm_fixdir }}/*SpcCoeff.bin"
#       prepbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.prepbufr.tm00'
#       satwndbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.satwnd.tm00.bufr_d'
#       l2rwbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.nexrad.tm00.bufr_d'
#       amsuabufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.1bamua.tm00.bufr_d'
#       amsuabufrears: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.esamua.tm00.bufr_d'
#       mhsbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.1bmhs.tm00.bufr_d'
#       mhsbufrears: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.esmhs.tm00.bufr_d'
#       atmsbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.atms.tm00.bufr_d'
#       atmsbufrears: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.esatms.tm00.bufr_d'
#       atmsbufr_db: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.atmsdb.tm00.bufr_d'
#       crisfsbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.crisf4.tm00.bufr_d'
#       crisfsbufr_db: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.crsfdb.tm00.bufr_d'
#       iasibufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.mtiasi.tm00.bufr_d'
#       iasibufrears: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.esiasi.tm00.bufr_d'
#       iasibufr_db: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.iasidb.tm00.bufr_d'
#       abibufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.gsrcsr.tm00.bufr_d'
#       ssmisbufr: '{{ platform.obspath }}/{{ timevars.yyyymmddhh }}.rap.t{{ timevars.hh }}z.ssmisu.tm00.bufr_d'
#     namelist:
#       base_file: '{{ user.uw_training }}/parm/gsiparm.anl'
#     obs_input_file: '{{ user.uw_training }}/parm/obs_input.txt'
#     rundir: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/analysis'
#   platform:
#     scheduler: slurm
#     account: wrfruc
# make_ics:
#   chgres_cube:
#     execution:
#       batchargs: &id012
#         nodes: 1
#         tasks_per_node: 20
#         walltime: 00:30:00
#       envcmds: &id013
#       - module use {{ user.rrfs_workflow }}/modulefiles
#       - module load build_hera_intel
#       executable: '{{ user.rrfs_workflow }}/exec/chgres_cube'
#       mpiargs: &id014
#       - --export=ALL
#       mpicmd: srun
#     namelist:
#       update_values:
#         config:
#           convert_atm: true
#           convert_nst: false
#           convert_sfc: true
#           cycle_day: &id015 !int "{{ (cycle + leadtime).strftime('%d') }}"
#           cycle_hour: &id016 !int "{{ (cycle + leadtime).strftime('%H') }}"
#           cycle_mon: &id017 !int "{{ (cycle + leadtime).strftime('%m') }}"
#           data_dir_input_grid: '{{ platform.input_data }}/gfs'
#           external_model: GFS
#           fix_dir_target_grid: '{{ platform.fix_lam }}'
#           grib2_file_input_grid: GFS-{{ timevars.yyyymmdd }}-{{ timevars.hh }}-f{{ timevars.fff }}.grib2
#           halo_blend: 20
#           halo_bndy: 4
#           input_type: grib2
#           lai_from_climo: true
#           minmax_vgfrc_from_climo: true
#           mosaic_file_target_grid: '{{ platform.fix_lam }}/C775_mosaic.halo4.nc'
#           nsoill_out: 4
#           orog_dir_target_grid: '{{ platform.fix_lam }}'
#           orog_files_target_grid: C775_oro_data.tile7.halo4.nc
#           regional: 1
#           sotyp_from_climo: true
#           tg3_from_soil: false
#           varmap_file: '{{ user.rrfs_workflow }}/sorc/UFS_UTILS/parm/varmap_tables/GFSphys_var_map.txt'
#           vcoord_file_target_grid: '{{ platform.fix_am }}/global_hyblev_fcst_rrfsL65.txt'
#           vgfrc_from_climo: true
#           vgtyp_from_climo: true
#     rundir: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/ics'
#   platform:
#     account: wrfruc
#     scheduler: slurm
# make_lbcs:
#   chgres_cube:
#     execution:
#       batchargs: *id012
#       envcmds: *id013
#       executable: '{{ user.rrfs_workflow }}/exec/chgres_cube'
#       mpiargs: *id014
#       mpicmd: srun
#     namelist:
#       update_values:
#         config:
#           convert_atm: true
#           convert_nst: false
#           convert_sfc: true
#           cycle_day: *id015
#           cycle_hour: *id016
#           cycle_mon: *id017
#           data_dir_input_grid: '{{ platform.input_data }}/gfs'
#           external_model: GFS
#           fix_dir_target_grid: '{{ platform.fix_lam }}'
#           grib2_file_input_grid: GFS-{{ timevars.yyyymmdd }}-{{ timevars.hh }}-f{{ timevars.fff }}.grib2
#           halo_blend: 20
#           halo_bndy: 4
#           input_type: grib2
#           lai_from_climo: true
#           minmax_vgfrc_from_climo: true
#           mosaic_file_target_grid: '{{ platform.fix_lam }}/C775_mosaic.halo4.nc'
#           nsoill_out: 4
#           orog_dir_target_grid: '{{ platform.fix_lam }}'
#           orog_files_target_grid: C775_oro_data.tile7.halo4.nc
#           regional: 2
#           sotyp_from_climo: true
#           tg3_from_soil: false
#           varmap_file: '{{ user.rrfs_workflow }}/sorc/UFS_UTILS/parm/varmap_tables/GFSphys_var_map.txt'
#           vcoord_file_target_grid: '{{ platform.fix_am }}/global_hyblev_fcst_rrfsL65.txt'
#           vgfrc_from_climo: true
#           vgtyp_from_climo: true
#     rundir: '{{ user.expt_dir }}/{{ timevars.yyyymmddhh }}/lbcs/{{ timevars.yyyymmddhh }}_{{ timevars.fff }}'
#   platform:
#     account: wrfruc
#     scheduler: slurm
# workflow:
#   attrs:
#     realtime: false
#     scheduler: slurm
#   cycledef:
#   - attrs:
#       group: cold_start_cycle
#     spec: 202508271200 202508271200 01:00:00
#   - attrs:
#       group: prod
#     spec: 202508271300 202508271300 01:00:00
#   entities:
#     ACCOUNT: '{{ user.account }}'
#     LOGDIR: '{{ user.expt_dir}}/log'
#   log:
#     value: '{{ user.expt_dir }}/workflow.log'
#   tasks:
#     task_prepare_ics:
#       attrs:
#         cycledefs: cold_start_cycle
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime 0 -c {{ user.uw_training }}/configs/prepare_bcs.yaml --key-path make_ics
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: '{{ make_ics.chgres_cube.execution.batchargs.nodes }}:ppn={{ make_ics.chgres_cube.execution.batchargs.tasks_per_node }}'
#       walltime: '{{ make_ics.chgres_cube.execution.batchargs.walltime }}'
#     metatask_prepare_lbcs:
#       var:
#         LEADTIME: '{% for fh in range(0, 6) %}{{ "%d " % fh }}{% endfor %}'
#       task_prepare_ics_#LEADTIME#:
#         attrs:
#           cycledefs: cold_start_cycle
#         account: '&ACCOUNT;'
#         command:
#           cyclestr:
#             value: 'uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime #LEADTIME# -c {{ user.uw_training }}/configs/prepare_bcs.yaml --key-path make_lbcs'
#         join:
#           cyclestr:
#             value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#         nodes: '{{ make_lbcs.chgres_cube.execution.batchargs.nodes }}:ppn={{ make_lbcs.chgres_cube.execution.batchargs.tasks_per_node }}'
#         walltime: '{{ make_lbcs.chgres_cube.execution.batchargs.walltime }}'
#     task_forecast_coldstart:
#       attrs:
#         cycledefs: cold_start_cycle
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw fv3 run --cycle @Y-@m-@dT@H -c {{ user.uw_training }}/configs/fv3_config.yaml --key-path forecast_prod
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: '{{ forecast_prod.fv3.execution.batchargs.nodes }}:ppn={{ forecast_prod.fv3.execution.batchargs.tasks_per_node }}'
#       walltime: '{{ forecast_prod.fv3.execution.batchargs.walltime }}'
#       dependency:
#         and:
#           taskdep_ics:
#             attrs:
#               task: prepare_ics
#           metataskdep_lbcs:
#             attrs:
#               metatask: prepare_lbcs
#     task_analysis:
#       attrs:
#         cycledefs: prod
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw gsi run --cycle @Y-@m-@dT@H -c {{ user.uw_training }}/configs/gsi_uw_config.yaml --key-path analysis
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       cores: !int "{{ analysis.gsi.execution.batchargs.cores }}"
#       walltime: '{{ analysis.gsi.execution.batchargs.walltime }}'
#       dependency:
#         or:
#           taskdep_forecast_coldstart:
#             attrs:
#               cycle_offset: -01:00:00
#               task: forecast_coldstart
#           taskdep_forecast_cycled:
#             attrs:
#               cycle_offset: -01:00:00
#               task: forecast_cycled
#     task_forecast_cycled:
#       attrs:
#         cycledefs: prod
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: '{{ user.uw_training }}/scripts/run_forecast.sh {{ user.uw_training }}/configs/fv3_config.yaml @Y-@m-@dT@H'
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: '{{ cycled_forecast.fv3.execution.batchargs.nodes }}:ppn={{ cycled_forecast.fv3.execution.batchargs.tasks_per_node }}'
#       walltime: '{{ cycled_forecast.fv3.execution.batchargs.walltime }}'
#       dependency:
#         taskdep:
#           attrs:
#             task: analysis

# %% [markdown]
# ### `compose` and `realize`

# %%
# %%bash
# file_list=(
#     $configs/fv3_config.yaml
#     $configs/gsi_config.yaml
#     $configs/prepare_bcs.yaml
#     $configs/rocoto_workflow.yaml
# )
# uw config compose ${file_list[*]} -o experiment.yaml --realize

# %%
# !cat experiment.yaml
# Out:
# timevars:
#   pyyyymmddhh: '{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}'
#   pyyyymmdd: '{{ (cycle - user.cycle_int).strftime("%Y%m%d") }}'
#   yyyymmddhh: '{{ cycle.strftime("%Y%m%d%H") }}'
#   yyyymmdd: '{{ cycle.strftime("%Y%m%d") }}'
#   hh: '{{ cycle.strftime("%H") }}'
#   yyyy: '{{ cycle.strftime("%Y") }}'
#   mm: '{{ cycle.strftime("%m") }}'
#   dd: '{{ cycle.strftime("%d") }}'
#   fff: '{{ "%03d" % (leadtime.total_seconds() / 3600) }}'
# user:
#   uw_training: /scratch3/BMC/wrfruc/uw_training/uwtools_training
#   expt_dir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7
#   rrfs_workflow: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow
#   physics_suite: FV3_HRRR_gf
#   cycle_int: !timedelta '1:00:00'
#   account: zrtrr
#   cycle_freq: !timedelta '1:00:00'
# platform:
#   scheduler: slurm
#   fix: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS
#   fix_am: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am
#   fix_lam: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV
#   input_data: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data
#   gsi_fixdir: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi
#   crtm_fixdir: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix
#   obspath: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs
# forecast_prod:
#   fv3:
#     diag_table:
#       template_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/diag_table.FV3_HRRR_gf
#       template_values:
#         cres: C775
#         starttime: &id001 !datetime "{{ cycle }}"
#     domain: regional
#     execution:
#       batchargs:
#         nodes: 4
#         tasks_per_node: 21
#         walltime: 00:45:00
#       envcmds:
#       - ulimit -s unlimited
#       - module use /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/modulefiles
#       - module load build_hera_intel
#       executable: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/exec/ufs_model
#       mpiargs:
#       - --export=ALL
#       - --mem=0
#       mpicmd: srun
#       threads: 1
#     field_table:
#       base_file: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/parm/field_table.FV3_HRRR_gf
#     files_to_copy:
#       INPUT/gfs_ctrl.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/ics/gfs_ctrl.nc
#       INPUT/gfs_data.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/ics/out.atm.tile7.nc
#       INPUT/sfc_data.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/ics/out.sfc.tile7.nc
#       ufs.configure: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/ufs.configure
#       fd_ufs.yaml: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/fd_ufs.yaml
#     files_to_link:
#       INPUT/grid_spec.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_mosaic.halo3.nc
#       INPUT/grid.tile7.halo4.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_grid.tile7.halo4.nc
#       INPUT/C775_grid.tile7.halo3.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_grid.tile7.halo3.nc
#       INPUT/oro_data.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data.tile7.halo0.nc
#       INPUT/oro_data.tile7.halo4.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data.tile7.halo4.nc
#       INPUT/oro_data_ls.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data_ls.tile7.halo0.nc
#       INPUT/oro_data_ss.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data_ss.tile7.halo0.nc
#       aerosol.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_climaeropac_global.txt
#       co2historicaldata_2010.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2010.txt
#       co2historicaldata_2011.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2011.txt
#       co2historicaldata_2012.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2012.txt
#       co2historicaldata_2013.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2013.txt
#       co2historicaldata_2014.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2014.txt
#       co2historicaldata_2015.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2015.txt
#       co2historicaldata_2016.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2016.txt
#       co2historicaldata_2017.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2017.txt
#       co2historicaldata_2018.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2018.txt
#       co2historicaldata_2019.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2019.txt
#       co2historicaldata_2020.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2020.txt
#       co2historicaldata_2021.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2021.txt
#       co2historicaldata_glob.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_co2historicaldata_glob.txt
#       co2monthlycyc.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/co2monthlycyc.txt
#       global_h2oprdlos.f77: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_h2o_pltc.f77
#       global_albedo4.1x1.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_albedo4.1x1.grb
#       global_zorclim.1x1.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_zorclim.1x1.grb
#       global_tg3clim.2.6x1.5.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_tg3clim.2.6x1.5.grb
#       sfc_emissivity_idx.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_sfc_emissivity_idx.txt
#       solarconstant_noaa_an.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_solarconstant_noaa_an.txt
#       global_o3prdlos.f77: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/ozprdlos_2015_new_sbuvO3_tclm15_nuchem.f77
#       CCN_ACTIVATE.BIN: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/CCN_ACTIVATE.BIN
#       freezeH2O.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/freezeH2O.dat
#       qr_acr_qg.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qg.dat
#       qr_acr_qgV2.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qgV2.dat
#       qr_acr_qs.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qs.dat
#       qr_acr_qsV2.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qsV2.dat
#       Thompson_MP_MONTHLY_CLIMO.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/Thompson_MP_MONTHLY_CLIMO.nc
#       <optics_file>: &id002 !glob '{{ platform.fix_am }}/optics_*.dat'
#       <aeroclim_file>: &id003 !glob '{{ platform.fix_am }}/aeroclim.m*.nc'
#     lateral_boundary_conditions:
#       interval_hours: 1
#       offset: 0
#       path: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/lbcs/{{ cycle.strftime("%Y%m%d%H") }}_{forecast_hour:03d}/gfs.bndy.nc
#     length: 3
#     model_configure:
#       update_values:
#         start_year: &id004 !int '{{ cycle.year }}'
#         start_month: &id005 !int '{{ cycle.month }}'
#         start_day: &id006 !int '{{ cycle.day }}'
#         start_hour: &id007 !int '{{ cycle.hour }}'
#         start_minute: &id008 !int '{{ cycle.minute }}'
#         start_second: &id009 !int '{{ cycle.second }}'
#         nhours_fcst: 3
#         fhrot: 0
#         run_continue: false
#         ens_sps: false
#         dt_atmos: 120
#         calendar: julian
#         memuse_verbose: false
#         restart_interval: 1
#         output_1st_tstep_rst: false
#         write_dopost: false
#         ideflate: 0
#         nbits: 0
#         ichunk2d: -1
#         jchunk2d: -1
#         ichunk3d: -1
#         jchunk3d: -1
#         kchunk3d: -1
#         itasks: 1
#         quilting: true
#         write_groups: 1
#         write_tasks_per_group: 4
#         num_files: 2
#         filename_base: dyn phy
#         output_file: netcdf netcdf
#         output_fh: 1  -1
#         nsout: -1
#         output_grid: lambert_conformal
#         cen_lon: -97.5
#         cen_lat: 38.5
#         stdlat1: 38.5
#         stdlat2: 38.5
#         nx: 420
#         ny: 252
#         dx: 13000.0
#         dy: 13000.0
#     namelist:
#       base_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/input.nml
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/fcst
#   platform:
#     scheduler: slurm
#     account: zrtrr
# cycled_forecast:
#   fv3:
#     diag_table:
#       template_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/diag_table.FV3_HRRR_gf
#       template_values:
#         cres: C775
#         starttime: *id001
#     domain: regional
#     execution:
#       batchargs:
#         nodes: 4
#         tasks_per_node: 21
#         walltime: 00:45:00
#       envcmds:
#       - ulimit -s unlimited
#       - module use /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/modulefiles
#       - module load build_hera_intel
#       executable: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/exec/ufs_model
#       mpiargs:
#       - --export=ALL
#       - --mem=0
#       mpicmd: srun
#       threads: 1
#     field_table:
#       base_file: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/parm/field_table.FV3_HRRR_gf
#     files_to_copy:
#       INPUT/fv_core.res.tile1.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_core.res.tile1.nc
#       INPUT/fv_srf_wnd.res.tile1.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_srf_wnd.res.tile1.nc
#       INPUT/fv_tracer.res.tile1.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_tracer.res.tile1.nc
#       INPUT/phy_data.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.phy_data.nc
#       INPUT/sfc_data.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.sfc_data.nc
#       INPUT/bk_coupler.res: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.coupler.res
#       INPUT/fv_core.res.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_core.res.nc
#       INPUT/gfs_ctrl.nc: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst/INPUT/gfs_ctrl.nc
#       ufs.configure: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/ufs.configure
#       fd_ufs.yaml: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm//fd_ufs.yaml
#     files_to_link:
#       INPUT/grid_spec.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_mosaic.halo3.nc
#       INPUT/grid.tile7.halo4.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_grid.tile7.halo4.nc
#       INPUT/C775_grid.tile7.halo3.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_grid.tile7.halo3.nc
#       INPUT/oro_data.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data.tile7.halo0.nc
#       INPUT/oro_data.tile7.halo4.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data.tile7.halo4.nc
#       INPUT/oro_data_ls.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data_ls.tile7.halo0.nc
#       INPUT/oro_data_ss.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_oro_data_ss.tile7.halo0.nc
#       aerosol.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_climaeropac_global.txt
#       co2historicaldata_2010.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2010.txt
#       co2historicaldata_2011.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2011.txt
#       co2historicaldata_2012.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2012.txt
#       co2historicaldata_2013.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2013.txt
#       co2historicaldata_2014.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2014.txt
#       co2historicaldata_2015.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2015.txt
#       co2historicaldata_2016.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2016.txt
#       co2historicaldata_2017.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2017.txt
#       co2historicaldata_2018.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2018.txt
#       co2historicaldata_2019.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2019.txt
#       co2historicaldata_2020.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2020.txt
#       co2historicaldata_2021.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/fix_co2_proj/global_co2historicaldata_2021.txt
#       co2historicaldata_glob.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_co2historicaldata_glob.txt
#       co2monthlycyc.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/co2monthlycyc.txt
#       global_h2oprdlos.f77: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_h2o_pltc.f77
#       global_albedo4.1x1.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_albedo4.1x1.grb
#       global_zorclim.1x1.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_zorclim.1x1.grb
#       global_tg3clim.2.6x1.5.grb: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_tg3clim.2.6x1.5.grb
#       sfc_emissivity_idx.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_sfc_emissivity_idx.txt
#       solarconstant_noaa_an.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_solarconstant_noaa_an.txt
#       global_o3prdlos.f77: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/ozprdlos_2015_new_sbuvO3_tclm15_nuchem.f77
#       CCN_ACTIVATE.BIN: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/CCN_ACTIVATE.BIN
#       freezeH2O.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/freezeH2O.dat
#       qr_acr_qg.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qg.dat
#       qr_acr_qgV2.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qgV2.dat
#       qr_acr_qs.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qs.dat
#       qr_acr_qsV2.dat: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/qr_acr_qsV2.dat
#       Thompson_MP_MONTHLY_CLIMO.nc: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/Thompson_MP_MONTHLY_CLIMO.nc
#       <optics_file>: *id002
#       <aeroclim_file>: *id003
#     lateral_boundary_conditions:
#       interval_hours: 1
#       offset: 1
#       path: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/lbcs/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}_{forecast_hour:03d}/gfs.bndy.nc
#     length: 3
#     model_configure:
#       update_values:
#         start_year: *id004
#         start_month: *id005
#         start_day: *id006
#         start_hour: *id007
#         start_minute: *id008
#         start_second: *id009
#         nhours_fcst: 3
#         fhrot: 0
#         run_continue: true
#         ens_sps: false
#         dt_atmos: 120
#         calendar: julian
#         memuse_verbose: false
#         restart_interval: 1
#         output_1st_tstep_rst: false
#         write_dopost: false
#         ideflate: 0
#         nbits: 0
#         ichunk2d: -1
#         jchunk2d: -1
#         ichunk3d: -1
#         jchunk3d: -1
#         kchunk3d: -1
#         itasks: 1
#         quilting: true
#         write_groups: 1
#         write_tasks_per_group: 4
#         num_files: 2
#         filename_base: dyn phy
#         output_file: netcdf netcdf
#         output_fh: 1  -1
#         nsout: -1
#         output_grid: lambert_conformal
#         cen_lon: -97.5
#         cen_lat: 38.5
#         stdlat1: 38.5
#         stdlat2: 38.5
#         nx: 420
#         ny: 252
#         dx: 13000.0
#         dy: 13000.0
#     namelist:
#       base_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/input.nml
#       update_values:
#         fv_core_nml:
#           external_ic: false
#           make_nh: false
#           mountain: true
#           na_init: 0
#           nggps_ic: false
#           warm_start: true
#         gfs_physics_nml:
#           lsoil: 9
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/fcst
#   platform:
#     scheduler: slurm
#     account: zrtrr
# forecast:
#   fv3:
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ (cycle - user.cycle_freq).strftime("%Y%m%d%H") }}/fcst
# gsi:
#   foo: bar
# analysis:
#   gsi:
#     execution:
#       batchargs:
#         walltime: 00:50:00
#         cores: 120
#         exclusive: true
#       executable: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/exec/gsi.x
#       envcmds:
#       - module use /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/modulefiles
#       - module load build_hera_intel
#       - ulimit -s unlimited
#       mpicmd: srun
#       stacksize: 300M
#       threads: 1
#     coupler.res:
#       template_file: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/RRFS_CONUS_13km/fv3_coupler.res
#       template_values:
#         yyyy: '{{ cycle.strftime("%Y") }}'
#         mm: '{{ cycle.strftime("%m") }}'
#         dd: '{{ cycle.strftime("%d") }}'
#         hh: '{{ cycle.strftime("%H") }}'
#         crh: bar
#     files_to_copy:
#       anavinfo: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/anavinfo.rrfs_conv_dbz
#       berror_stats: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/rrfs_glb_berror.l127y770.f77
#       satinfo: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/global_satinfo.txt
#       convinfo: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/convinfo.rrfs
#       ozinfo: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/global_ozinfo.txt
#       pcpinfo: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/global_pcpinfo.txt
#       errtable: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/errtable.rrfs
#       atms_beamwidth.txt: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/atms_beamwidth.txt
#     files_to_link:
#       fv3_akbk: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/RRFS_CONUS_13km/fv3_akbk
#       fv3_grid_spec: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/gsi/RRFS_CONUS_13km/fv3_grid_spec
#       fv3_dynvars: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_core.res.tile1.nc'
#       fv3_tracer: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.fv_tracer.res.tile1.nc'
#       fv3_sfcdata: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.sfc_data.nc'
#       fv3_phyvars: '{{ user.expt_dir }}/{{ timevars.pyyyymmddhh }}/fcst/RESTART/{{ cycle.strftime("%Y%m%d") }}.{{ cycle.strftime("%H") }}0000.phy_data.nc'
#       crtm_coeffs/Nalli.IRwater.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/Nalli.IRwater.EmisCoeff.bin
#       crtm_coeffs/NPOESS.IRice.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.IRice.EmisCoeff.bin
#       crtm_coeffs/NPOESS.IRsnow.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.IRsnow.EmisCoeff.bin
#       crtm_coeffs/NPOESS.IRland.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.IRland.EmisCoeff.bin
#       crtm_coeffs/NPOESS.VISice.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.VISice.EmisCoeff.bin
#       crtm_coeffs/NPOESS.VISland.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.VISland.EmisCoeff.bin
#       crtm_coeffs/NPOESS.VISsnow.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.VISsnow.EmisCoeff.bin
#       crtm_coeffs/NPOESS.VISwater.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/NPOESS.VISwater.EmisCoeff.bin
#       crtm_coeffs/FASTEM6.MWwater.EmisCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/FASTEM6.MWwater.EmisCoeff.bin
#       crtm_coeffs/AerosolCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/AerosolCoeff.bin
#       crtm_coeffs/CloudCoeff.bin: /contrib/spack-stack/spack-stack-1.6.0/envs/unified-env-rocky8/install/intel/2021.5.0/crtm-fix-2.4.0.1_emc-zvwtu3t/fix/CloudCoeff.bin
#       crtm_coeffs/<tau>: !glob "{{ platform.crtm_fixdir }}/*TauCoeff.bin"
#       crtm_coeffs/<spc>: !glob "{{ platform.crtm_fixdir }}/*SpcCoeff.bin"
#       prepbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.prepbufr.tm00
#       satwndbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.satwnd.tm00.bufr_d
#       l2rwbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.nexrad.tm00.bufr_d
#       amsuabufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.1bamua.tm00.bufr_d
#       amsuabufrears: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.esamua.tm00.bufr_d
#       mhsbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.1bmhs.tm00.bufr_d
#       mhsbufrears: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.esmhs.tm00.bufr_d
#       atmsbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.atms.tm00.bufr_d
#       atmsbufrears: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.esatms.tm00.bufr_d
#       atmsbufr_db: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.atmsdb.tm00.bufr_d
#       crisfsbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.crisf4.tm00.bufr_d
#       crisfsbufr_db: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.crsfdb.tm00.bufr_d
#       iasibufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.mtiasi.tm00.bufr_d
#       iasibufrears: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.esiasi.tm00.bufr_d
#       iasibufr_db: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.iasidb.tm00.bufr_d
#       abibufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.gsrcsr.tm00.bufr_d
#       ssmisbufr: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/rap_obs/{{ cycle.strftime("%Y%m%d%H") }}.rap.t{{ cycle.strftime("%H") }}z.ssmisu.tm00.bufr_d
#     namelist:
#       base_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/gsiparm.anl
#     obs_input_file: /scratch3/BMC/wrfruc/uw_training/uwtools_training/parm/obs_input.txt
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/analysis
#   platform:
#     scheduler: slurm
#     account: wrfruc
# make_ics:
#   chgres_cube:
#     execution:
#       batchargs:
#         nodes: 1
#         tasks_per_node: 20
#         walltime: 00:30:00
#       envcmds:
#       - module use /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/modulefiles
#       - module load build_hera_intel
#       executable: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/exec/chgres_cube
#       mpiargs:
#       - --export=ALL
#       mpicmd: srun
#     namelist:
#       update_values:
#         config:
#           convert_atm: true
#           convert_nst: false
#           convert_sfc: true
#           cycle_day: &id010 !int "{{ (cycle + leadtime).strftime('%d') }}"
#           cycle_hour: &id011 !int "{{ (cycle + leadtime).strftime('%H') }}"
#           cycle_mon: &id012 !int "{{ (cycle + leadtime).strftime('%m') }}"
#           data_dir_input_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/gfs
#           external_model: GFS
#           fix_dir_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV
#           grib2_file_input_grid: GFS-{{ cycle.strftime("%Y%m%d") }}-{{ cycle.strftime("%H") }}-f{{ "%03d" % (leadtime.total_seconds() / 3600) }}.grib2
#           halo_blend: 20
#           halo_bndy: 4
#           input_type: grib2
#           lai_from_climo: true
#           minmax_vgfrc_from_climo: true
#           mosaic_file_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_mosaic.halo4.nc
#           nsoill_out: 4
#           orog_dir_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV
#           orog_files_target_grid: C775_oro_data.tile7.halo4.nc
#           regional: 1
#           sotyp_from_climo: true
#           tg3_from_soil: false
#           varmap_file: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/sorc/UFS_UTILS/parm/varmap_tables/GFSphys_var_map.txt
#           vcoord_file_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_hyblev_fcst_rrfsL65.txt
#           vgfrc_from_climo: true
#           vgtyp_from_climo: true
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/ics
#   platform:
#     account: wrfruc
#     scheduler: slurm
# make_lbcs:
#   chgres_cube:
#     execution:
#       batchargs:
#         nodes: 1
#         tasks_per_node: 20
#         walltime: 00:30:00
#       envcmds:
#       - module use /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/modulefiles
#       - module load build_hera_intel
#       executable: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/exec/chgres_cube
#       mpiargs:
#       - --export=ALL
#       mpicmd: srun
#     namelist:
#       update_values:
#         config:
#           convert_atm: true
#           convert_nst: false
#           convert_sfc: true
#           cycle_day: *id010
#           cycle_hour: *id011
#           cycle_mon: *id012
#           data_dir_input_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/input_data/gfs
#           external_model: GFS
#           fix_dir_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV
#           grib2_file_input_grid: GFS-{{ cycle.strftime("%Y%m%d") }}-{{ cycle.strftime("%H") }}-f{{ "%03d" % (leadtime.total_seconds() / 3600) }}.grib2
#           halo_blend: 20
#           halo_bndy: 4
#           input_type: grib2
#           lai_from_climo: true
#           minmax_vgfrc_from_climo: true
#           mosaic_file_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV/C775_mosaic.halo4.nc
#           nsoill_out: 4
#           orog_dir_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/lam/RRFS_CONUS_13km_Lake_fracSV
#           orog_files_target_grid: C775_oro_data.tile7.halo4.nc
#           regional: 2
#           sotyp_from_climo: true
#           tg3_from_soil: false
#           varmap_file: /scratch3/BMC/wrfruc/cholt/rrfs_work/rrfs-workflow/sorc/UFS_UTILS/parm/varmap_tables/GFSphys_var_map.txt
#           vcoord_file_target_grid: /scratch3/BMC/wrfruc/cholt/rrfs_work/FIX_RRFS/am/global_hyblev_fcst_rrfsL65.txt
#           vgfrc_from_climo: true
#           vgtyp_from_climo: true
#     rundir: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/{{ cycle.strftime("%Y%m%d%H") }}/lbcs/{{ cycle.strftime("%Y%m%d%H") }}_{{ "%03d" % (leadtime.total_seconds() / 3600) }}
#   platform:
#     account: wrfruc
#     scheduler: slurm
# workflow:
#   attrs:
#     realtime: false
#     scheduler: slurm
#   cycledef:
#   - attrs:
#       group: cold_start_cycle
#     spec: 202508271200 202508271200 01:00:00
#   - attrs:
#       group: prod
#     spec: 202508271300 202508271300 01:00:00
#   entities:
#     ACCOUNT: zrtrr
#     LOGDIR: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/log
#   log:
#     value: /scratch3/BMC/wrfruc/cholt/uw_training_prep/expt7/workflow.log
#   tasks:
#     task_prepare_ics:
#       attrs:
#         cycledefs: cold_start_cycle
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime 0 -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_ics
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: 1:ppn=20
#       walltime: 00:30:00
#     metatask_prepare_lbcs:
#       var:
#         LEADTIME: '0 1 2 3 4 5 '
#       task_prepare_ics_#LEADTIME#:
#         attrs:
#           cycledefs: cold_start_cycle
#         account: '&ACCOUNT;'
#         command:
#           cyclestr:
#             value: 'uw chgres_cube run --cycle @Y-@m-@dT@H --leadtime #LEADTIME# -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/prepare_bcs.yaml --key-path make_lbcs'
#         join:
#           cyclestr:
#             value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#         nodes: 1:ppn=20
#         walltime: 00:30:00
#     task_forecast_coldstart:
#       attrs:
#         cycledefs: cold_start_cycle
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw fv3 run --cycle @Y-@m-@dT@H -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/fv3_config.yaml --key-path forecast_prod
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: 4:ppn=21
#       walltime: 00:45:00
#       dependency:
#         and:
#           taskdep_ics:
#             attrs:
#               task: prepare_ics
#           metataskdep_lbcs:
#             attrs:
#               metatask: prepare_lbcs
#     task_analysis:
#       attrs:
#         cycledefs: prod
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: uw gsi run --cycle @Y-@m-@dT@H -c /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/gsi_uw_config.yaml --key-path analysis
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       cores: 120
#       walltime: 00:50:00
#       dependency:
#         or:
#           taskdep_forecast_coldstart:
#             attrs:
#               cycle_offset: -01:00:00
#               task: forecast_coldstart
#           taskdep_forecast_cycled:
#             attrs:
#               cycle_offset: -01:00:00
#               task: forecast_cycled
#     task_forecast_cycled:
#       attrs:
#         cycledefs: prod
#       account: '&ACCOUNT;'
#       command:
#         cyclestr:
#           value: /scratch3/BMC/wrfruc/uw_training/uwtools_training/scripts/run_forecast.sh /scratch3/BMC/wrfruc/uw_training/uwtools_training/configs/fv3_config.yaml @Y-@m-@dT@H
#       join:
#         cyclestr:
#           value: '&LOGDIR;/{{ jobname }}_@Y@m@d@H.log'
#       nodes: 4:ppn=21
#       walltime: 00:45:00
#       dependency:
#         taskdep:
#           attrs:
#             task: analysis

# %% [markdown]
# ## Visually inspect the Rocoto XML
#
# * Check to make sure there are no remaining Jinja2 expressions that got past the validator.
# * Did any loops end up off by one?
# * Anything else amiss?

# %% [markdown]
# ## Run the Rocoto Workflow
#
# Docs: __[uw rocoto iterate](https://uwtools.readthedocs.io/en/main/sections/user_guide/cli/tools/rocoto.html#iterate)__
#
# The `uw rocoto iterate` tool iteratively runs `rocotorun` and `rocotostat` in subprocesses at a default interval of 10 s to step through the workflow until a particular cycle and task are complete.

# %%
# %%bash
# module load rocoto
# uw rocoto iterate -w workflow.xml -d workflow.db --cycle 2025-08-27T13 --task cycled_forecast
